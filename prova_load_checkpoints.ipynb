# %%
from minde.minde import MINDE
from omegaconf import OmegaConf

# %%
checkpoint_path = r"/home/foresti/minde/minde/evaluate/minde/checkpoints_unet/lightning_logs/version_234_correct_generation_rectangles/checkpoints/epoch=9999-step=200000.ckpt"
model_conf_path = r"/home/foresti/minde/minde/evaluate/config.d/estimator/minde_unet.yaml"

MINDE.load_from_checkpoint(checkpoint_path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 4
#       1 checkpoint_path = r"/home/foresti/minde/minde/evaluate/minde/checkpoints_unet/lightning_logs/version_234_correct_generation_rectangles/checkpoints/epoch=9999-step=200000.ckpt"
#       2 model_conf_path = r"/home/foresti/minde/minde/evaluate/config.d/estimator/minde_unet.yaml"
# ----> 4 MINDE.load_from_checkpoint(checkpoint_path)
#
# File /home/foresti/miniconda3/envs/minde/lib/python3.10/site-packages/pytorch_lightning/utilities/model_helpers.py:125, in _restricted_classmethod_impl.__get__.<locals>.wrapper(*args, **kwargs)
#     120 if instance is not None and not is_scripting:
#     121     raise TypeError(
#     122         f"The classmethod `{cls.__name__}.{self.method.__name__}` cannot be called on an instance."
# ...

# %%
model.initialize_model()
# Out:
# ---------------------------------------------------------------------------
# ConfigAttributeError                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.initialize_model()
#
# File /home/foresti/minde/minde/minde.py:43, in MINDE.initialize_model(self)
#      37 def initialize_model(self):
#      39     """
#      40     Initialize the model.
#      41     """
# ---> 43     if hasattr(self.args.model, 'hidden_dim')==False or self.args.model.hidden_dim == None:
#      44         hidden_dim = self.calculate_hidden_dim()
#      45     else:
#
# File /home/foresti/miniconda3/envs/minde/lib/python3.10/site-packages/omegaconf/dictconfig.py:355, in DictConfig.__getattr__(self, key)
#     351     return self._get_impl(
#     352         key=key, default_value=_DEFAULT_MARKER_, validate_key=False
#     353     )
#     354 except ConfigKeyError as e:
# --> 355     self._format_and_raise(
# ...
